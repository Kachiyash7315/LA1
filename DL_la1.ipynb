# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from keras.datasets import boston_housing


(train_data, train_targets), (test_data, test_targets) = boston_housing.load_data()

# Concatenate train and test data
all_data = np.concatenate((train_data, test_data), axis=0)
all_targets = np.concatenate((train_targets, test_targets), axis=0)

# Convert to DataFrame
column_names = ['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT', 'PRICE']
df = pd.DataFrame(data=all_data, columns=column_names[:-1])  # Exclude the target column
df['PRICE'] = all_targets  # Add target column

# Save DataFrame to CSV
df.to_csv('housing.csv', index=False)
df = pd.read_csv('housing.csv')
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/boston_housing.npz
# 57026/57026 [==============================] - 0s 0us/step

# %%
df.head(5)
# Out:
#       CRIM   ZN  INDUS  CHAS    NOX     RM    AGE     DIS   RAD    TAX  \
# 0  1.23247  0.0   8.14   0.0  0.538  6.142   91.7  3.9769   4.0  307.0
# 1  0.03961  0.0   5.19   0.0  0.515  6.037   34.5  5.9853   5.0  224.0
# 2  3.69311  0.0  18.10   0.0  0.713  6.376   88.4  2.5671  24.0  666.0
# 3  0.28392  0.0   7.38   0.0  0.493  5.708   74.3  4.7211   5.0  287.0
# 4  9.18702  0.0  18.10   0.0  0.700  5.536  100.0  1.5804  24.0  666.0
#
#    PTRATIO       B  LSTAT  PRICE
# 0     21.0  396.90  18.72   15.2
# 1     20.2  396.90   8.01   21.1
# 2     20.2  391.43  14.65   17.7
# 3     19.6  391.13  11.74   18.5
# 4     20.2  396.90  23.60   11.3

# %%
print(np.shape(df))
# Out:
# (506, 14)

# %%
print(df.describe())
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  458.000000  458.000000  458.000000  458.000000  458.000000  458.000000
# mean     3.880713   10.180131   11.588166    0.058952    0.558875    6.156945
# std      8.973996   21.950057    6.756057    0.235792    0.117724    0.563489
# min      0.006320    0.000000    0.740000    0.000000    0.385000    3.561000
# 25%      0.084020    0.000000    5.860000    0.000000    0.453000    5.871250
# 50%      0.256510    0.000000    9.900000    0.000000    0.538000    6.152000
# 75%      4.082653    0.000000   18.100000    0.000000    0.624000    6.481750
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  458.000000  458.000000  458.000000  458.000000  458.000000  458.000000
# mean    69.170524    3.807797    9.842795  417.893013   18.676201  353.521965
# std     28.008853    2.125004    8.884462  168.736868    2.027875   95.363794
# min      2.900000    1.137000    1.000000  187.000000   12.600000    0.320000
# 25%     45.725000    2.100175    4.000000  287.000000   17.600000  373.105000
# 50%     78.400000    3.199200    5.000000  345.000000   19.200000  391.880000
# 75%     94.300000    5.214600   24.000000  666.000000   20.200000  396.397500
# max    100.000000   12.126500   24.000000  711.000000   22.000000  396.900000
#
#             LSTAT       PRICE
# count  458.000000  458.000000
# mean    13.490699   20.320087
# std      6.967358    6.185151
# min      1.980000    5.000000
# 25%      7.927500   16.200000
# 50%     12.370000   20.400000
# 75%     17.302500   23.800000
# max     37.970000   34.900000

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats

fig, axs = plt.subplots(ncols=7, nrows=2, figsize=(20, 10))
index = 0
axs = axs.flatten()
for k,v in df.items():
    sns.boxplot(y=k, data=df, ax=axs[index])
    index += 1
plt.tight_layout(pad=0.4, w_pad=0.5, h_pad=5.0)

# %%
 for k, v in df.items():
        q1 = v.quantile(0.25)
        q3 = v.quantile(0.75)
        irq = q3 - q1
        v_col = v[(v <= q1 - 1.5 * irq) | (v >= q3 + 1.5 * irq)]
        perc = np.shape(v_col)[0] * 100.0 / np.shape(df)[0]
        print("Column %s outliers = %.2f%%" % (k, perc))
# Out:
# Column CRIM outliers = 13.04%
# Column ZN outliers = 13.44%
# Column INDUS outliers = 0.00%
# Column CHAS outliers = 100.00%
# Column NOX outliers = 0.00%
# Column RM outliers = 5.93%
# Column AGE outliers = 0.00%
# Column DIS outliers = 0.99%
# Column RAD outliers = 0.00%
# Column TAX outliers = 0.00%
# Column PTRATIO outliers = 2.96%
# Column B outliers = 15.22%
# Column LSTAT outliers = 1.38%
# Column PRICE outliers = 7.91%

# %%
df = df[~(df['PRICE'] >= 35.0)]
print(np.shape(df))
# Out:
# (458, 14)

# %%
df.head()
# Out:
#       CRIM   ZN  INDUS  CHAS    NOX     RM    AGE     DIS   RAD    TAX  \
# 0  1.23247  0.0   8.14   0.0  0.538  6.142   91.7  3.9769   4.0  307.0
# 1  0.03961  0.0   5.19   0.0  0.515  6.037   34.5  5.9853   5.0  224.0
# 2  3.69311  0.0  18.10   0.0  0.713  6.376   88.4  2.5671  24.0  666.0
# 3  0.28392  0.0   7.38   0.0  0.493  5.708   74.3  4.7211   5.0  287.0
# 4  9.18702  0.0  18.10   0.0  0.700  5.536  100.0  1.5804  24.0  666.0
#
#    PTRATIO       B  LSTAT  PRICE
# 0     21.0  396.90  18.72   15.2
# 1     20.2  396.90   8.01   21.1
# 2     20.2  391.43  14.65   17.7
# 3     19.6  391.13  11.74   18.5
# 4     20.2  396.90  23.60   11.3

# %%
print(df.shape)
# Out:
# (458, 14)

# %%
df.isnull().sum()
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# PRICE      0
# dtype: int64

# %%
df.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  458.000000  458.000000  458.000000  458.000000  458.000000  458.000000
# mean     3.880713   10.180131   11.588166    0.058952    0.558875    6.156945
# std      8.973996   21.950057    6.756057    0.235792    0.117724    0.563489
# min      0.006320    0.000000    0.740000    0.000000    0.385000    3.561000
# 25%      0.084020    0.000000    5.860000    0.000000    0.453000    5.871250
# 50%      0.256510    0.000000    9.900000    0.000000    0.538000    6.152000
# 75%      4.082653    0.000000   18.100000    0.000000    0.624000    6.481750
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  458.000000  458.000000  458.000000  458.000000  458.000000  458.000000
# mean    69.170524    3.807797    9.842795  417.893013   18.676201  353.521965
# std     28.008853    2.125004    8.884462  168.736868    2.027875   95.363794
# min      2.900000    1.137000    1.000000  187.000000   12.600000    0.320000
# 25%     45.725000    2.100175    4.000000  287.000000   17.600000  373.105000
# 50%     78.400000    3.199200    5.000000  345.000000   19.200000  391.880000
# 75%     94.300000    5.214600   24.000000  666.000000   20.200000  396.397500
# max    100.000000   12.126500   24.000000  711.000000   22.000000  396.900000
#
#             LSTAT       PRICE
# count  458.000000  458.000000
# mean    13.490699   20.320087
# std      6.967358    6.185151
# min      1.980000    5.000000
# 25%      7.927500   16.200000
# 50%     12.370000   20.400000
# 75%     17.302500   23.800000
# max     37.970000   34.900000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 458 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     458 non-null    float64
#  1   ZN       458 non-null    float64
#  2   INDUS    458 non-null    float64
#  3   CHAS     458 non-null    float64
#  4   NOX      458 non-null    float64
#  5   RM       458 non-null    float64
#  6   AGE      458 non-null    float64
#  7   DIS      458 non-null    float64
#  8   RAD      458 non-null    float64
#  9   TAX      458 non-null    float64
#  10  PTRATIO  458 non-null    float64
#  11  B        458 non-null    float64
#  12  LSTAT    458 non-null    float64
#  13  PRICE    458 non-null    float64
# dtypes: float64(14)
# memory usage: 53.7 KB

# %% [markdown]
# **Visualization**

# %%
import seaborn as sns
sns.histplot(df.PRICE , kde = True)
# Out:
# <Axes: xlabel='PRICE', ylabel='Count'>

# %%
sns.boxplot(df.PRICE)
# Out:
# <Axes: ylabel='PRICE'>

# %%
correlation = df.corr()
correlation.loc['PRICE']
# Out:
# CRIM      -0.509111
# ZN         0.432791
# INDUS     -0.598380
# CHAS       0.098362
# NOX       -0.584249
# RM         0.540151
# AGE       -0.571890
# DIS        0.461164
# RAD       -0.515860
# TAX       -0.587285
# PTRATIO   -0.471471
# B          0.404020
# LSTAT     -0.780531
# PRICE      1.000000
# Name: PRICE, dtype: float64

# %%
import matplotlib.pyplot as plt
fig,axes = plt.subplots(figsize=(15,12))
sns.heatmap(correlation,square = True,annot = True)
# Out:
# <Axes: >

# %%
plt.figure(figsize = (20,5))
features = ['LSTAT','RM','PTRATIO']
for i, col in enumerate(features):
    plt.subplot(1, len(features) , i+1)
    x = df[col]
    y = df.PRICE
    plt.scatter(x, y, marker='o')
    plt.title("Variation in House prices")
    plt.xlabel(col)
    plt.ylabel('"House prices in $1000"')

# %%
X = df.iloc[:,:-1]
y= df.PRICE

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.2, random_state = 4)

# %% [markdown]
# **Building the Model**

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()

# %%
regressor.fit(X_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# **Model Evaluation**

# %%
y_pred = regressor.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error
rmse = (np.sqrt(mean_squared_error(y_test, y_pred)))
print(rmse)
# Out:
# 3.39631439267756

# %%
from sklearn.metrics import r2_score
r2 = r2_score(y_test, y_pred)
print(r2)
# Out:
# 0.6844487162303876

# %% [markdown]
# **Neural Networks**

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
#Creating the neural network model
import keras
from keras.layers import Dense, Activation,Dropout
from keras.models import Sequential

model = Sequential()

model.add(Dense(128,activation  = 'relu',input_dim =13))
model.add(Dense(64,activation  = 'relu'))
model.add(Dense(32,activation  = 'relu'))
model.add(Dense(16,activation  = 'relu'))
model.add(Dense(1))
model.compile(optimizer = 'adam',loss = 'mean_squared_error')

# %%
model.fit(X_train, y_train, epochs = 100)
# Out:
# Epoch 1/100
# 12/12 [==============================] - 1s 3ms/step - loss: 445.6649
# Epoch 2/100
# 12/12 [==============================] - 0s 3ms/step - loss: 417.7429
# Epoch 3/100
# 12/12 [==============================] - 0s 2ms/step - loss: 337.8915
# Epoch 4/100
# 12/12 [==============================] - 0s 2ms/step - loss: 173.8250
# Epoch 5/100
# 12/12 [==============================] - 0s 3ms/step - loss: 55.2605
# Epoch 6/100
# 12/12 [==============================] - 0s 3ms/step - loss: 29.5454
# Epoch 7/100
# 12/12 [==============================] - 0s 3ms/step - loss: 21.0158
# Epoch 8/100
# 12/12 [==============================] - 0s 3ms/step - loss: 15.7623
# Epoch 9/100
# 12/12 [==============================] - 0s 3ms/step - loss: 13.3219
# Epoch 10/100
# 12/12 [==============================] - 0s 3ms/step - loss: 11.8466
# Epoch 11/100
# 12/12 [==============================] - 0s 2ms/step - loss: 10.8855
# Epoch 12/100
# 12/12 [==============================] - 0s 3ms/step - loss: 10.2240
# Epoch 13/100
# 12/12 [==============================] - 0s 3ms/step - loss: 9.5686
# Epoch 14/100
# 12/12 [==============================] - 0s 3ms/step - loss: 9.0450
# Epoch 15/100
# 12/12 [==============================] - 0s 3ms/step - loss: 8.6507
# Epoch 16/100
# 12/12 [==============================] - 0s 3ms/step - loss: 8.3276
# Epoch 17/100
# 12/12 [==============================] - 0s 3ms/step - loss: 7.9744
# Epoch 18/100
# 12/12 [==============================] - 0s 3ms/step - loss: 7.7131
# Epoch 19/100
# 12/12 [==============================] - 0s 3ms/step - loss: 7.4164
# Epoch 20/100
# 12/12 [==============================] - 0s 3ms/step - loss: 7.2818
# Epoch 21/100
# 12/12 [==============================] - 0s 3ms/step - loss: 7.1232
# Epoch 22/100
# 12/12 [==============================] - 0s 3ms/step - loss: 6.9636
# Epoch 23/100
# 12/12 [==============================] - 0s 3ms/step - loss: 6.6863
# Epoch 24/100
# 12/12 [==============================] - 0s 3ms/step - loss: 6.5585
# Epoch 25/100
# 12/12 [==============================] - 0s 2ms/step - loss: 6.5009
# Epoch 26/100
# 12/12 [==============================] - 0s 3ms/step - loss: 6.2882
# Epoch 27/100
# 12/12 [==============================] - 0s 3ms/step - loss: 6.1915
# Epoch 28/100
# 12/12 [==============================] - 0s 3ms/step - loss: 6.0600
# Epoch 29/100
# 12/12 [==============================] - 0s 3ms/step - loss: 5.8157
# Epoch 30/100
# 12/12 [==============================] - 0s 2ms/step - loss: 5.7419
# Epoch 31/100
# 12/12 [==============================] - 0s 2ms/step - loss: 5.7696
# Epoch 32/100
# 12/12 [==============================] - 0s 2ms/step - loss: 5.6100
# Epoch 33/100
# 12/12 [==============================] - 0s 2ms/step - loss: 5.5496
# Epoch 34/100
# 12/12 [==============================] - 0s 2ms/step - loss: 5.3663
# Epoch 35/100
# 12/12 [==============================] - 0s 2ms/step - loss: 5.3112
# Epoch 36/100
# 12/12 [==============================] - 0s 2ms/step - loss: 5.2187
# Epoch 37/100
# 12/12 [==============================] - 0s 2ms/step - loss: 5.1947
# Epoch 38/100
# 12/12 [==============================] - 0s 3ms/step - loss: 5.2583
# Epoch 39/100
# 12/12 [==============================] - 0s 3ms/step - loss: 5.2983
# Epoch 40/100
# 12/12 [==============================] - 0s 3ms/step - loss: 4.8509
# Epoch 41/100
# 12/12 [==============================] - 0s 3ms/step - loss: 4.7630
# Epoch 42/100
# 12/12 [==============================] - 0s 2ms/step - loss: 4.7136
# Epoch 43/100
# 12/12 [==============================] - 0s 2ms/step - loss: 4.6631
# Epoch 44/100
# 12/12 [==============================] - 0s 3ms/step - loss: 4.6652
# Epoch 45/100
# 12/12 [==============================] - 0s 2ms/step - loss: 4.6133
# Epoch 46/100
# 12/12 [==============================] - 0s 2ms/step - loss: 4.5132
# Epoch 47/100
# 12/12 [==============================] - 0s 3ms/step - loss: 4.5418
# Epoch 48/100
# 12/12 [==============================] - 0s 3ms/step - loss: 4.4244
# Epoch 49/100
# 12/12 [==============================] - 0s 2ms/step - loss: 4.3306
# Epoch 50/100
# 12/12 [==============================] - 0s 2ms/step - loss: 4.2931
# Epoch 51/100
# 12/12 [==============================] - 0s 2ms/step - loss: 4.2692
# Epoch 52/100
# 12/12 [==============================] - 0s 2ms/step - loss: 4.1860
# Epoch 53/100
# 12/12 [==============================] - 0s 3ms/step - loss: 4.0487
# Epoch 54/100
# 12/12 [==============================] - 0s 2ms/step - loss: 4.0422
# Epoch 55/100
# 12/12 [==============================] - 0s 2ms/step - loss: 3.9522
# Epoch 56/100
# 12/12 [==============================] - 0s 2ms/step - loss: 4.0436
# Epoch 57/100
# 12/12 [==============================] - 0s 2ms/step - loss: 3.7874
# Epoch 58/100
# 12/12 [==============================] - 0s 2ms/step - loss: 3.7861
# Epoch 59/100
# 12/12 [==============================] - 0s 2ms/step - loss: 3.7161
# Epoch 60/100
# 12/12 [==============================] - 0s 2ms/step - loss: 3.6865
# Epoch 61/100
# 12/12 [==============================] - 0s 2ms/step - loss: 3.6566
# Epoch 62/100
# 12/12 [==============================] - 0s 2ms/step - loss: 3.5576
# Epoch 63/100
# 12/12 [==============================] - 0s 2ms/step - loss: 3.5338
# Epoch 64/100
# 12/12 [==============================] - 0s 2ms/step - loss: 3.5805
# Epoch 65/100
# 12/12 [==============================] - 0s 2ms/step - loss: 3.5030
# Epoch 66/100
# 12/12 [==============================] - 0s 2ms/step - loss: 3.4883
# Epoch 67/100
# 12/12 [==============================] - 0s 2ms/step - loss: 3.3538
# Epoch 68/100
# 12/12 [==============================] - 0s 2ms/step - loss: 3.4718
# Epoch 69/100
# 12/12 [==============================] - 0s 2ms/step - loss: 3.3360
# Epoch 70/100
# 12/12 [==============================] - 0s 3ms/step - loss: 3.2959
# Epoch 71/100
# 12/12 [==============================] - 0s 3ms/step - loss: 3.1607
# Epoch 72/100
# 12/12 [==============================] - 0s 4ms/step - loss: 3.2076
# Epoch 73/100
# 12/12 [==============================] - 0s 4ms/step - loss: 3.2433
# Epoch 74/100
# 12/12 [==============================] - 0s 4ms/step - loss: 3.0936
# Epoch 75/100
# 12/12 [==============================] - 0s 4ms/step - loss: 3.0007
# Epoch 76/100
# 12/12 [==============================] - 0s 3ms/step - loss: 2.9659
# Epoch 77/100
# 12/12 [==============================] - 0s 3ms/step - loss: 2.9939
# Epoch 78/100
# 12/12 [==============================] - 0s 4ms/step - loss: 2.9635
# Epoch 79/100
# 12/12 [==============================] - 0s 4ms/step - loss: 2.8675
# Epoch 80/100
# 12/12 [==============================] - 0s 3ms/step - loss: 2.8084
# Epoch 81/100
# 12/12 [==============================] - 0s 3ms/step - loss: 2.8234
# Epoch 82/100
# 12/12 [==============================] - 0s 3ms/step - loss: 2.8196
# Epoch 83/100
# 12/12 [==============================] - 0s 4ms/step - loss: 2.8272
# Epoch 84/100
# 12/12 [==============================] - 0s 4ms/step - loss: 2.7328
# Epoch 85/100
# 12/12 [==============================] - 0s 4ms/step - loss: 2.6600
# Epoch 86/100
# 12/12 [==============================] - 0s 4ms/step - loss: 2.7057
# Epoch 87/100
# 12/12 [==============================] - 0s 4ms/step - loss: 2.6160
# Epoch 88/100
# 12/12 [==============================] - 0s 3ms/step - loss: 2.6171
# Epoch 89/100
# 12/12 [==============================] - 0s 4ms/step - loss: 2.6137
# Epoch 90/100
# 12/12 [==============================] - 0s 3ms/step - loss: 2.5000
# Epoch 91/100
# 12/12 [==============================] - 0s 3ms/step - loss: 2.5255
# Epoch 92/100
# 12/12 [==============================] - 0s 3ms/step - loss: 2.4617
# Epoch 93/100
# 12/12 [==============================] - 0s 4ms/step - loss: 2.4016
# Epoch 94/100
# 12/12 [==============================] - 0s 4ms/step - loss: 2.4417
# Epoch 95/100
# 12/12 [==============================] - 0s 3ms/step - loss: 2.5061
# Epoch 96/100
# 12/12 [==============================] - 0s 3ms/step - loss: 2.4023
# Epoch 97/100
# 12/12 [==============================] - 0s 3ms/step - loss: 2.3648
# Epoch 98/100
# 12/12 [==============================] - 0s 3ms/step - loss: 2.5491
# Epoch 99/100
# 12/12 [==============================] - 0s 3ms/step - loss: 2.4286
# Epoch 100/100
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2554

# %%
y_pred = model.predict(X_test)
# Out:
# 3/3 [==============================] - 0s 4ms/step

# %%
from sklearn.metrics import r2_score
r2 = r2_score(y_test, y_pred)
print(r2)
# Out:
# 0.6672936618399188

# %%
# Predicting RMSE the Test set results
from sklearn.metrics import mean_squared_error
rmse = (np.sqrt(mean_squared_error(y_test, y_pred)))
print(rmse)
# Out:
# 3.487413521313821
